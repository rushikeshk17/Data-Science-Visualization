# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### DATA

# %%
data2 = pd.read_csv(r"C:\Users\ASUS\Downloads\Data_CPI\All_India_Index_july2019_20Aug2020_dec20_1_2.csv")

# %%
data2.tail(10)
data2.head(10)
# Out:
#         Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0        Rural  2013   January                 107.5          106.3  108.1
# 1        Urban  2013   January                 110.5          109.1  113.0
# 2  Rural+Urban  2013   January                 108.4          107.3  110.0
# 3        Rural  2013  February                 109.2          108.7  110.2
# 4        Urban  2013  February                 112.9          112.9  116.9
# 5  Rural+Urban  2013  February                 110.4          110.2  112.8
# 6        Rural  2013     March                 110.2          108.8  109.9
# 7        Urban  2013     March                 113.9          111.4  113.2
# 8  Rural+Urban  2013     March                 111.4          109.7  111.2
# 9        Rural  2013     April                 110.2          109.5  106.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0              104.9          106.1   103.9       101.9  ...      NaN
# ...

# %%
data2.shape
# Out:
# (318, 30)

# %%
df.reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2912/529044471.py in <module>
# ----> 1 df.reset_index(drop = True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Scatter plot

# %%
df = data2[data2['Year']==2018]
df = df[df['Sector']=='Rural']
df2 = data2[data2['Year']==2020]
df2 = df2[df2['Sector']=='Rural']

# %%
y = df['General index']
y2 = df2['General index']

# %%
plt.figure(figsize = (10,7))
plt.scatter(y,y2)
plt.xlabel('Index for year 2020',size = 15)
plt.ylabel('Index for year 2018',size = 15)
plt.xlim(138,162)
plt.ylim(138,162)
plt.title('General Consumer Price Index for different Years',size = 15)
plt.grid()
plt.show()

# %% [markdown]
# ## BOX Plot

# %%
data2
# Out:
#           Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0          Rural  2013   January                 107.5          106.3  108.1
# 1          Urban  2013   January                 110.5          109.1  113.0
# 2    Rural+Urban  2013   January                 108.4          107.3  110.0
# 3          Rural  2013  February                 109.2          108.7  110.2
# 4          Urban  2013  February                 112.9          112.9  116.9
# ..           ...   ...       ...                   ...            ...    ...
# 313        Urban  2021   October                 150.1          208.4  173.0
# 314  Rural+Urban  2021   October                 147.4          204.6  171.2
# 315        Rural  2021  November                 146.9          199.8  171.5
# 316        Urban  2021  November                 151.0          204.9  175.4
# 317  Rural+Urban  2021  November                 148.2          201.6  173.0
#
# ...

# %%
y1 = list(data2[data2['Sector']=='Rural']['General index'])
y1 = [x for x in y1 if str(x) != 'nan']
y2 = list(data2[data2['Sector']=='Urban']['General index'])
y2 = [x for x in y2 if str(x) != 'nan']
y3 = list(data2[data2['Sector']=='Rural+Urban']['General index'])
y3 = [x for x in y3 if str(x) != 'nan']
y = [y1,y2,y3]

# %%
x = ['Rural', 'Urban' , 'Rural+Urban']
plt.figure(figsize = (10,7))
plt.boxplot(y)
plt.xticks([1,2,3],x,size = 15)
plt.ylabel('Index',size = 15)
plt.title('CPI distribution',size = 15)
plt.grid()
plt.show()

# %% [markdown]
# ## Line plot

# %%
df = data2[data2['Year']==2021]
df.reset_index(drop = True)
# Out:
#          Sector  Year      Month  Cereals and products  Meat and fish    Egg  \
# 0         Rural  2021    January                 143.4          187.5  173.4
# 1         Urban  2021    January                 148.0          194.8  178.4
# 2   Rural+Urban  2021    January                 144.9          190.1  175.3
# 3         Rural  2021   February                 142.8          184.0  168.0
# 4         Urban  2021   February                 147.6          191.2  169.9
# 5   Rural+Urban  2021   February                 144.3          186.5  168.7
# 6         Rural  2021      March                 142.5          189.4  163.2
# 7         Urban  2021      March                 147.5          197.5  164.7
# 8   Rural+Urban  2021      March                 144.1          192.2  163.8
# 9         Rural  2021      April                 142.7          195.5  163.4
# 10        Urban  2021      April                 147.6          202.5  166.4
# ...

# %%
x = df[df['Sector']=='Rural']['Month']
y = df[df['Sector']=='Rural']['General index']
x2 = df[df['Sector']=='Urban']['Month']
y2 = df[df['Sector']=='Urban']['General index']
x3 = df[df['Sector']=='Rural+Urban']['Month']
y3 = df[df['Sector']=='Rural+Urban']['General index']

# %%
plt.figure(figsize = (10,7))
plt.plot(x,y,'go-', label='Rural', linewidth=2)
plt.plot(x2,y2,'r*-', label='Urban', linewidth=2)
plt.plot(x3,y3,'bx-', label='Urban', linewidth=2)
plt.xlabel('Month',size = 15)
plt.ylabel('Index',size = 15)
plt.title('General Consumer Price Index vs Month of Year',size = 15)
plt.legend()
plt.grid()
plt.show()
